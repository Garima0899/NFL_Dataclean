# %%
import pandas as pd,numpy as np
import matplotlib.pyplot as plt,seaborn as sns

# %%
nfl_data=pd.read_csv('NFL Play by Play 2009-2017 (v4).csv')
sf_permits = pd.read_csv('Building_Permits.csv')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2416\1525184058.py:1: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   nfl_data=pd.read_csv('NFL Play by Play 2009-2017 (v4).csv')
# C:\Users\hp\AppData\Local\Temp\ipykernel_2416\1525184058.py:2: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   sf_permits = pd.read_csv('Building_Permits.csv')

# %%
nfl_data.head()
# Out:
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# 3          41.0         PIT  ... -5.031425     0.510793     0.489207
# 4           8.0         PIT  ...       NaN     0.461217     0.538783
#
#    Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# ...

# %%
sf_permits.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# ...

# %%
nfl_data.columns
# Out:
# Index(['Date', 'GameID', 'Drive', 'qtr', 'down', 'time', 'TimeUnder',
#        'TimeSecs', 'PlayTimeDiff', 'SideofField',
#        ...
#        'yacEPA', 'Home_WP_pre', 'Away_WP_pre', 'Home_WP_post', 'Away_WP_post',
#        'Win_Prob', 'WPA', 'airWPA', 'yacWPA', 'Season'],
#       dtype='object', length=102)

# %%
missing = nfl_data.isnull().sum()

# %%
missing[missing>0]
# Out:
# down             61154
# time               224
# TimeSecs           224
# PlayTimeDiff       444
# SideofField        528
#                  ...
# Away_WP_post     26587
# Win_Prob         25009
# WPA               5541
# airWPA          248501
# yacWPA          248762
# Length: 65, dtype: int64

# %%
missing[10:20]
# Out:
# yrdln              840
# yrdline100         840
# ydstogo              0
# ydsnet               0
# GoalToGo           840
# FirstDown        28811
# posteam          24992
# DefensiveTeam    24992
# desc                 2
# PlayAttempted        0
# dtype: int64

# %%
missing[20:30]
# Out:
# Yards.Gained          0
# sp                    0
# Touchdown             0
# ExPointResult    397578
# TwoPointConv     407083
# DefTwoPoint      407664
# Safety                0
# Onsidekick            0
# PuntResult       385317
# PlayType              0
# dtype: int64

# %%
missing2 = sf_permits.isnull().sum()

# %%
missing2[missing2>0]
# Out:
# Street Number Suffix                      196684
# Street Suffix                               2768
# Unit                                      169421
# Unit Suffix                               196939
# Description                                  290
# Issued Date                                14940
# Completed Date                            101709
# First Construction Document Date           14946
# Structural Notification                   191978
# Number of Existing Stories                 42784
# Number of Proposed Stories                 42868
# Voluntary Soft-Story Retrofit             198865
# Fire Only Permit                          180073
# Permit Expiration Date                     51880
# Estimated Cost                             38066
# Revised Cost                                6066
# Existing Use                               41114
# Existing Units                             51538
# Proposed Use                               42439
# ...

# %%
missing2.sum()
# Out:
# 2245941

# %%
missing.sum()
# Out:
# 11505187

# %%
nfl_data.shape
# Out:
# (407688, 102)

# %%
total_cells = np.product(nfl_data.shape)
total_cells
# Out:
# 41584176

# %%
percentage = (missing.sum()/total_cells)*100
percentage
# Out:
# 27.66722370547874

# %%
total_cells2 = np.product(sf_permits.shape)
total_cells2
# Out:
# 8552700

# %%
percentage2 = (missing2.sum()/total_cells2)*100
percentage2
# Out:
# 26.26002315058403

# %%
droped = nfl_data.dropna(axis = 1)
droped
# Out:
#               Date      GameID  Drive  qtr  TimeUnder  ydstogo  ydsnet  \
# 0       2009-09-10  2009091000      1    1         15        0       0
# 1       2009-09-10  2009091000      1    1         15       10       5
# 2       2009-09-10  2009091000      1    1         15        5       2
# 3       2009-09-10  2009091000      1    1         14        8       2
# 4       2009-09-10  2009091000      1    1         14        8       2
# ...            ...         ...    ...  ...        ...      ...     ...
# 407683  2017-12-31  2017123101     29    4          1        0      -4
# 407684  2017-12-31  2017123101     29    4          1       14      -4
# 407685  2017-12-31  2017123101     29    4          1       14       9
# 407686  2017-12-31  2017123101     30    4          1       10      -1
# 407687  2017-12-31  2017123101     30    4          0        0      -1
#
#         PlayAttempted  Yards.Gained  sp  ...  AwayTeam  Timeout_Indicator  \
# ...

# %%
print('original data:',nfl_data.shape[1])
print('removed data:',droped.shape[1])
# Out:
# original data: 102
# removed data: 37

# %%
# taking small subset
subset = nfl_data.loc[:,'EPA':'Season'].head()
subset
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474       NaN       NaN     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760       NaN       NaN     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796       NaN       NaN     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758       NaN       NaN    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295       NaN       NaN    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712       NaN       NaN    2009

# %%
nfl_data.sample(10)
# Out:
#               Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 153540  2012-10-28  2012102802     21    4   4.0  01:24          2      84.0
# 213284  2013-12-01  2013120108     18    4   2.0  09:45         10     585.0
# 43566   2010-01-03  2010010312     20    4   2.0  15:00         15     900.0
# 187632  2013-09-22  2013092205     11    2   4.0  01:43          2    1903.0
# 158479  2012-11-11  2012111103      9    2   1.0  02:46          3    1966.0
# 193713  2013-10-10  2013101000      5    1   1.0  00:48          1    2748.0
# 267682  2014-12-22  2014122200     11    2   1.0  07:56          8    2276.0
# 159374  2012-11-11  2012111106      7    2   NaN  06:27          7    2187.0
# 255222  2014-11-23  2014112302     22    3   NaN  03:02          4    1082.0
# 223002  2013-12-29  2013122911     18    4   NaN  10:44         11     644.0
#
#         PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# ...

# %%
filling_data = nfl_data.loc[:,'EPA':'Season'].fillna('0').head()
filling_data
# Out:
#         EPA    airEPA    yacEPA Home_WP_pre Away_WP_pre Home_WP_post  \
# 0  2.014474         0         0    0.485675    0.514325     0.546433
# 1  0.077907 -1.068169  1.146076    0.546433    0.453567     0.551088
# 2  -1.40276         0         0    0.551088    0.448912     0.510793
# 3 -1.712583  3.318841 -5.031425    0.510793    0.489207     0.461217
# 4  2.097796         0         0    0.461217    0.538783     0.558929
#
#   Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0     0.453567  0.485675  0.060758         0         0    2009
# 1     0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2     0.489207  0.551088 -0.040295         0         0    2009
# 3     0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4     0.441071  0.461217  0.097712         0         0    2009

# %%
filling_data = nfl_data.loc[:,'EPA':'Season'].fillna(method = 'bfill').head(5)
filling_data  #
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2416\285033583.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filling_data = nfl_data.loc[:,'EPA':'Season'].fillna(method = 'bfill').head(5)
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474 -1.068169  1.146076     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  3.318841 -5.031425     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796 -0.343085  0.163935     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758 -0.032244  0.036899    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.106663 -0.156239    2009
# ...

# %%
sf_permits.fillna(method = 'bfill', axis=0).fillna("0")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2416\3625929214.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   sf_permits.fillna(method = 'bfill', axis=0).fillna("0")
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# ...

# %%
subset.fillna(subset.mean(),inplace= True)
subset
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474  1.125336 -1.942674     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  1.125336 -1.942674     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  1.125336 -1.942674     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758  0.037209 -0.059670    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.037209 -0.059670    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712  0.037209 -0.059670    2009
